# %% [markdown]
# # Matplotlib.pyplot Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
x = np.linspace(0,10,150)
y = np.sin(x)
plt.plot(x, y)

# %%
plt.scatter(x, y)
