# %% [markdown]
# # Read Image Data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
image_data = plt.imread(r"/content/sample_data/bird.jpg") # R is for raw

print(type(image_data))

print(image_data.shape)

plt.imshow(image_data)

image_red_data = image_data[:,:,0:3]
print(image_red_data.shape)
plt.imshow(image_red_data)
# Out:
# <class 'numpy.ndarray'>
# (853, 1280, 3)
# (853, 1280, 3)
